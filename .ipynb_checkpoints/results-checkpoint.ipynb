# %%
import json
import pandas as pd
import missingno as msno
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
jb = pd.read_csv("jinbutsu.csv")

# %%
jb["birth_year"] = jb["birth_date"].apply(lambda x: int(x[:4]) if type(x) == str else None )

# %%
jb[jb["birth_year"]!=None]["birth_year"].hist(bins=19, figsize=(20,12))

# %%
jb["occupation"].value_counts()[:15].plot(kind="bar", figsize=(20,12))

# %%
jb["gender"].value_counts().plot(kind="pie", figsize=(8,8))

# %%
ja = pd.read_csv("jinbutsu_authors.csv")

# %%
ja["gender"].value_counts().plot(kind="pie", figsize=(8,8))

# %%
ja["education"].value_counts()[:15].plot(kind="bar", figsize=(20,12))
